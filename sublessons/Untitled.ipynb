# %%
import requests
import json

# %% [markdown]
# # Bird Apps

# %%
with open('/Users/johnmaxbarry/.ssh/cornell_ornithology.json', 'rb') as read_file:
    bird_key = json.load(read_file)

# %%
headers = {'X-eBirdApiToken': bird_key['key']}

# params = {'comName': 'Gold Finch', 'locName':'Central Park--Strawberry Field' }

# %%
central_park = requests.get('https://api.ebird.org/v2/data/obs/L191106/recent', headers=headers)

# %%
len(r.json())
# Out:
# 72

# %%
40.7812° N, 73.9665° W

# %%
bald_eagle = requests.get('https://api.ebird.org/v2/data/nearest/geo/recent/baleag/?lat=40.7812&lng=-73.9665', headers=headers)

# %%
bald_eagle.json()
# Out:
# [{'speciesCode': 'baleag',
#   'comName': 'Bald Eagle',
#   'sciName': 'Haliaeetus leucocephalus',
#   'locId': 'L12880944',
#   'locName': '125 W 92nd St, New York US-NY 40.79077, -73.97038',
#   'obsDt': '2020-12-06 07:56',
#   'howMany': 1,
#   'lat': 40.790765,
#   'lng': -73.970382,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S77129634'},
#  {'speciesCode': 'baleag',
#   'comName': 'Bald Eagle',
#   'sciName': 'Haliaeetus leucocephalus',
#   'locId': 'L191106',
#   'locName': 'Central Park',
#   'obsDt': '2020-12-07 09:50',
#   'howMany': 1,
#   'lat': 40.7715482,
#   'lng': -73.9724819,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S77193970'},
#  {'speciesCode': 'baleag',
#   'comName': 'Bald Eagle',
#   'sciName': 'Haliaeetus leucocephalus',
#   'locId': 'L4130150',
#   'locName': 'Home',
#   'obsDt': '2020-12-07 12:37',
#   'howMany': 4,
#   'lat': 40.7898118,
# ...
